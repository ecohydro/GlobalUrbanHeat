# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm
import seaborn as sns

# %%
fn = os.path.join('/home/cascade/CHIRTS/UEH-daily/stats/wbgtmax30_TREND_ALL.json')

# %%
trend = pd.read_json(fn, orient = 'split')

# %%
trend
# Out:
#       ID_HDC_G0   coef_pdays  p_value_pdays    coef_heat  p_value_heat  \
# 0            18  2472.019732         0.5191  1965.053764        0.5191
# 1            22   281.712286         0.5191   206.825938        0.5191
# 2            26  1477.435791         0.5191  1156.526598        0.5191
# 3            27   360.722938         0.5191   319.948094        0.5191
# 4            28   589.850324         0.5481   444.114223        0.5539
# ...         ...          ...            ...          ...           ...
# 7409      13119  2725.313591         0.0548  1288.682402        0.0998
# 7410      13120  3345.180762         0.0906  1997.412158        0.1350
# 7411      13123  1915.112997         0.0031   596.027056        0.0032
# 7412      13125  1143.390262         0.0250   674.991664        0.0302
# 7413      13135  9671.641848         0.0336  6073.420399        0.0333
#
#          coef_pop  p_value_pop  coef_totDays  p_value_totDays  coef_attrib  \
# ...

# %%
trend[trend['ID_HDC_G0'] == 33]

# %%
fn = os.path.join('/scratch/cascade/UEH-daily/stats/wbgtmax30_EXP.json')
exp = pd.read_json(fn, orient = 'split')

# %%
city = exp[exp['ID_HDC_G0'] == 33]
city.head(1)

# %%
X = list(city.sort_values('year')['year'].values) 
Y = list(city.sort_values('year')['tot_days'].values) 
Z = list(city.sort_values('year')['P'].values)
W = list((city.sort_values('year')['tot_days'] * city.sort_values('year')['P'].values).values)
W = np.nan_to_num(W, 0)
Q = list((city.sort_values('year')['tot_days'] * (city.sort_values('year')['P'] - 40107.651544).values).values)
Q = np.nan_to_num(Q, 0)

# %%
# plot the data itself

plt.plot(X,W,'o')

# calc the trendline
z = np.polyfit(X, W, 1)
p = np.poly1d(z)
plt.plot(x,p(x),"r--")
plt.title('coef_pdays is for city 33 is '+ str(int(p.c[0])) + ' person-days per year', fontsize=13);
plt.xlabel('year')
plt.ylabel('person-days')

# %%
# plot the data itself

plt.plot(X,Q,'o')

# calc the trendline
z = np.polyfit(X, Q, 1)
p = np.poly1d(z)
plt.plot(x,p(x),"r--")
plt.title('coef_pop is for city 33 is '+ str(int(p.c[0])) + ' person-days per year', fontsize=13);
plt.xlabel('year')
plt.ylabel('person-days')
